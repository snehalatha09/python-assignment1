# %% [markdown]
# #whether a person is eligible for voting or not

# %%
name='sneha'
age=int(input("enter the age of sneha"))
if age>=18:
  print("sneha is eligible for voting")
else:
    print("sneha is not eligible for voting")
# Out:
# enter the age of sneha19
# sneha is eligible for voting

# %% [markdown]
# #check whether aperson is even or odd

# %%
num=int(input("enter the number"))
if (num%2==0):
  print("the number is even")
else:
  print("the number is odd")
# Out:
# enter the number12
# the number is even

# %% [markdown]
# #check whether a number is positive or not

# %%
num=int(input("enter the number"))
if (num>0):
  print("number is positive")
else:
  print("number is negitive")
# Out:
# enter the number-12
# number is negitive

# %% [markdown]
# #check whether the charecter is vowel or consonent

# %%
ch=input("please enter your own charecterr")
if(ch=='a'or ch=='e' or ch=='i' or ch=='o' or ch=='u'):
   print("the given charecter",ch,"is a vowelt")
else :
 print("the given charecter is consonentl")
# Out:
# please enter your own charecterrs
# the given charecter is consonentl

# %% [markdown]
# #check whether a number is prime or not

# %%
num=int(input("enter the num"))
if num>1:
  for i in range(2,num):
    if (num%i)==0:
      print(num,"is not a primenumber")
      break
else :
        print(num,"is a prime number")
# Out:
# enter the num12
# 12 is not a primenumber

# %% [markdown]
# #quadratic equation

# %%
from math import sqrt
print("quadratic function:(a*X^2)+b*X+c")
a=float(input("a"))
b=float(input("b"))
c=float(input("c"))
r=b**2-4*a*c
if r>0:
   num_roots=2
   x1=(((-b)+sqrt(r))/(2*a))
   x2=(((-b)-sqrt(r))/(2*a))
   print("there are two roots"%f and %f%(x1,x2))
   elif r==0:
      num_roots=1
      x=(-b)/2*a
      print("there is one root:",x)
else:
  num_roots=0
  print("no roots,discriminate<0")

# %% [markdown]
# #print given digit in charecter

# %%
a=int(input("enter a num"))
if (a==1):
  print("one")
elif (a==2):
 print("two")
elif(a==3):
      print("three")
elif(a==4):
      print("four")
else:
        print("five")
# Out:
# enter a num1
# one

# %% [markdown]
# #check whether the number is positive or neitive or zero

# %%
num=int(input("enter the number"))
if num>0:
  print("positive number")
elif num==0:
    print("zero")
else:
      print("negitive number")
# Out:
# enter the number12
# positive number
