# %%
a=int(input("enter the value of a"))
b=int(input("enter the value of b"))
print(a+b)
print(a-b)
print(a/b)
print(a%b)
print(a**b)
print(a//b)
# Out:
# enter the value of a10
# enter the value of b5
# 15
# 5
# 2.0
# 0
# 100000
# 2

# %%
#simple interest

# %%
p=int(input("enter the value of a"))
t=int(input("enter the value of t"))
r=int(input("enter the value of t"))
si=(p*t*r)/100
print(si,":simple intrest")
# Out:
# enter the value of a12
# enter the value of t23
# enter the value of t3
# 8.28 :simple intrest

# %% [markdown]
# area of a circle

# %%
r=int(input("enter the value of radious"))
print("area of a circle is:",3.14*(r**2))
# Out:
# enter the value of radious6
# area of a circle is: 113.04

# %% [markdown]
# Area of triangle

# %%
b=int(input())
h=int(input())
print("area of trianglr is",(0.5*b*h))
# Out:
# 3
# 4
# area of trianglr is 6.0

# %% [markdown]
# Celsius to fahrenheit

# %%
t=43
f=(t*1.8)+32
print("the temp in fahrenheit is:",f)
# Out:
# the temp in fahrenheit is: 109.4

# %% [markdown]
# Area of rectangle

# %%
l=int(input("enter the length"))
b=int(input("enter the bredth"))
print("area of rectangle is:",l*b)
# Out:
# enter the length43
# enter the bredth23
# area of rectangle is: 989

# %% [markdown]
# #perimeter of a square

# %%
side=int(input("enter the side of a square"))
print("perimeter of the squre is:",4*side)
# Out:
# enter the side of a square9
# perimeter of the squre is: 36

# %% [markdown]
# #Circumference of a circle

# %%
r=int(input("enter the radius of the circle"))
print("the circumference of a circle is:",2*3.14*r)
# Out:
# enter the radius of the circle4
# the circumference of a circle is: 25.12

# %% [markdown]
# #swap two nummbers

# %%
a=4
b=3
tem=a
a=b
b=tem
print(a)
print(b)
# Out:
# 3
# 4
