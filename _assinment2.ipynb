# %% [markdown]
# #program1

# %%
a=int(input("enter the value ofa"))
b=int(input("enter the value of b"))
print("sum of two numbers;",a+b)
# Out:
# enter the value ofa2
# enter the value of b3
# sum of two numbers; 5

# %% [markdown]
# #programme 2

# %%
a=input("enter your name:")
# Out:
# enter your name:chech

# %%
print("hello chech")
# Out:
# hello chech

# %% [markdown]
# #programme3

# %%
a=int(input("enter hours"))
# Out:
# enter hours35

# %%
b=float(input("enter rate"))
# Out:
# enter rate2.75

# %%
c=a*b
print(c)
# Out:
# 96.25

# %% [markdown]
# #programme 3

# %%
width=17
height=12.0
print(width//2)
print(width/2.0)
print(height/3)
c=1+2*5
print(c)
# Out:
# 8
# 8.5
# 4.0
# 11

# %% [markdown]
# #programme4

# %%
t=43
f=t*1.8+32
print("The tem in forenheat",f)
# Out:
# The tem in forenheat 109.4
